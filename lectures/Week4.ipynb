# %% [markdown]
# ## Week 4
#
#
# Following our section on data collection, we shift focus to analyzing social data. The course will now cover basic tools in Network and Text Analysis, applying these to previously collected data. We start with Network Science.
#
# Networks, or graphs, are crucial for representing and analyzing social systems. This week introduces networks through three main topics:
#
# * __Context__: An overview of network science history and basic network concepts.
# * __The NetworkX Library__: Introduction to this Python library for network analysis.
# * __Basic Network Analysis:__ We will analyze and visualize the network of Computational Social Scientists using NetworkX.
#
# The objective is to ensure you learn about the field of network science and get hands-on experience using the NetworkX library for fundamental analysis.

# %% [markdown]
# # Part 1: Basic mathematical description of networks
#
# This week, let's start with some lecturing. First, we will go through the history of Network Science.
#
# > **_Video Lecture_**. Start by watching the "History of Networks"

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("kt6J36e0JCk",width=800, height=450)

# %% [markdown]
# > **_Video Lecture_**. Then check out a short video on "Network Notation"

# %%
YouTubeVideo("_AT9HaTE9nE",width=800, height=450)

# %% [markdown]
# > __Reading__. To better familiarize with basic concepts in Network Science, we will read two chapters in the _Network Science_ book by Laszlo Barabasi. You can read the whole
# > book for free [**here**](https://networksciencebook.com/).
# >
# > * [Read chapter 1](http://networksciencebook.com/chapter/1)
# > * [Read chapter 2](http://networksciencebook.com/chapter/2)
# >

# %% [markdown]
# # Prelude to Part 2: The NetworkX library

# %% [markdown]
# In this course, we will leverage the NetworkX Python library for network analysis. To effectively work with real-world networks, it is essential that you familiarize with NetworkX beforehand.
#
# > __Exercise__
# >
# > * Download the NetworkX project's [tutorial](https://networkx.org/documentation/stable/tutorial.html). Familiarize with the basics like creating graphs, accessing node and edge properties, and visualizing graphs.
# > * Experiment with the tutorial code. Feel free to tweak it to understand how things work.

# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_node(1)
G.add_nodes_from([2, 3])
G.add_nodes_from([(4, {"color": "red"}), (5, {"color": "green"})])

H = nx.path_graph(10)
G.add_nodes_from(H)

# %%
G.add_edge(1, 2)
e = (2, 3)
G.add_edge(*e)  # unpack edge tuple*

# %%
G.add_edges_from(H.edges)
G.clear()

# %%
G.add_edges_from([(1, 2), (1, 3)])
G.add_node(1)
G.add_edge(1, 2)
G.add_node("spam")        # adds node "spam"
G.add_nodes_from("spam")  # adds 4 nodes: 's', 'p', 'a', 'm'
G.add_edge(3, 'm')

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (8, 3)

# %% [markdown]
# # Part 2: Basic analysis of the network of Computational Social Scientists

# %% [markdown]
# Ok, enough with theory. It is time to go back to our dataset.
# We will build the network of Computational Social Scientists. Then, we will use some Network Science to study some of its properties.

# %% [markdown]
# > **Exercise 1: Constructing the Computational Social Scientists Network**
# >
# > In this exercise, we will create a network of researchers in the field of Computational Social Science using the NetworkX library. In our network, nodes represent authors of academic papers, with a direct link from node _A_ to node _B_ indicating a joint paper written by both. The link's weight reflects the number of papers written by both _A_ and _B_.
# >
# > **Part 1: Network Construction**
# >
# > 1. **Weighted Edgelist Creation:** Start with your dataframe of *papers*. Construct a _weighted edgelist_ where each list element is a tuple containing three elements: the _author ids_ of two collaborating authors and the total number of papers they've co-authored. Ensure each author pair is listed only once.
# >
# > 2. **Graph Construction:**
# >    - Use NetworkX to create an undirected [``Graph``](https://networkx.org/documentation/stable/reference/classes/graph.html).
# >    - Employ the [`add_weighted_edges_from`](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_weighted_edges_from.html#networkx.Graph.add_weighted_edges_from) function to populate the graph with the weighted edgelist from step 1, creating a weighted, undirected graph.
# >
# > 3. **Node Attributes:**
# >    - For each node, add attributes for the author's _display name_, _country_, _citation count_, and the _year of their first publication_ in Computational Social Science. This information should be retrieved from your _authors_ dataset. You can use the _papers_ dataset to retreive the total number of citations per author.
# >    - Save the network as a JSON file.
# >
# > **Part 2: Preliminary Network Analysis**
# > Now, with the network constructed, perform a basic analysis to explore its features.
# > 1. **Network Metrics:**
# >
# >    - What is the total number of nodes (authors) and links (collaborations) in the network?
# >    - Calculate the network's density (the ratio of actual links to the maximum possible number of links). Would you say that the network is sparse? Justify your answer.
# >    - Is the network fully connected (i.e., is there a direct or indirect path between every pair of nodes within the network), or is it disconnected?
# >    - If the network is disconnected, how many connected components does it have? A connected component is defined as a subset of nodes within the network where a path exists between any pair of nodes in that subset.
# >    - How many isolated nodes are there in your network?  An isolated node is defined as a node with no connections to any other node in the network.
# >    - Discuss the results above on network density, and connectivity. Are your findings in line with what you expected? Why?
# >
# > 3. **Degree Analysis:**
# >    - Compute the average, median, mode, minimum, and maximum degree of the nodes. Perform the same analysis for node strength (weighted degree). What do these metrics tell us about the network?
# >
# > 4. **Top Authors:**
# >    - Identify the top 5 authors by degree. What role do these node play in the network?
# >    - Research these authors online. What areas do they specialize in? Do you think that their work aligns with the themes of Computational Social Science? If not, what could be possible reasons?

# %% [markdown]
# # Part 1

# %%
import pandas as pd
import networkx as nx
import json
import ast
from itertools import combinations
from collections import Counter, defaultdict

# %%
PAPERS_PATH = "CSS_Papers_D2plusD5.csv"
AUTHORS_PATH = "CSS_Authors_D1plusD4.csv"

papers = pd.read_csv(PAPERS_PATH)
authors = pd.read_csv(AUTHORS_PATH)

print("papers cols:", papers.columns.tolist())
print("authors cols:", authors.columns.tolist())
papers.head()
# Out:
# papers cols: ['id', 'publication_year', 'cited_by_count', 'author_ids']
# authors cols: ['query_name', 'id', 'display_name', 'works_api_url', 'h_index', 'works_count', 'country_code', 'matched', 'cited_by_count']
#                                  id  publication_year  cited_by_count  \
# 0  https://openalex.org/W2047940964            2004.0            7318
# 1  https://openalex.org/W3103362336            2018.0            6724
# 2  https://openalex.org/W2157082398            2008.0            2162
# 3  https://openalex.org/W2061099285            2010.0             948
# 4  https://openalex.org/W2102017123            2015.0             592
#
#                                           author_ids
# 0  ['https://openalex.org/A5014647140', 'https://...
# 1  ['https://openalex.org/A5014647140', 'https://...
# 2  ['https://openalex.org/A5014647140', 'https://...
# 3  ['https://openalex.org/A5069948947', 'https://...
# 4  ['https://openalex.org/A5014647140', 'https://...

# %%
def parse_author_ids(x):
    if isinstance(x, list):
        return x
    if not isinstance(x, str):
        return []
    s = x.strip()
    if s == "" or s.lower() == "nan":
        return []
    # try JSON first
    try:
        out = json.loads(s)
        return out if isinstance(out, list) else []
    except Exception:
        pass
    # fallback: python literal list like "['a','b']"
    try:
        out = ast.literal_eval(s)
        return out if isinstance(out, list) else []
    except Exception:
        return []

# %%
papers["author_ids"] = papers["author_ids"].apply(parse_author_ids)

# sanity check: are we getting real lists?
lens = papers["author_ids"].apply(len)
print("author_ids length stats:", lens.describe())
print("Example author_ids:", papers["author_ids"].iloc[lens.idxmax()])
# Out:
# author_ids length stats: count    52468.000000
# mean         2.703305
# std          1.245407
# min          2.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          9.000000
# Name: author_ids, dtype: float64
# Example author_ids: ['https://openalex.org/A5066731285', 'https://openalex.org/A5063113082', 'https://openalex.org/A5090745602', 'https://openalex.org/A5090650053', 'https://openalex.org/A5054751614', 'https://openalex.org/A5061131179', 'https://openalex.org/A5086777696', 'https://openalex.org/A5091645410', 'https://openalex.org/A5056849976']

# %%
pair_counts = Counter()

for ids in papers["author_ids"]:
    # keep valid strings only, unique per paper
    ids = sorted({a for a in ids if isinstance(a, str) and a.startswith("http")})
    if len(ids) < 2:
        continue
    for a, b in combinations(ids, 2):
        pair_counts[(a, b)] += 1

weighted_edgelist = [(a, b, w) for (a, b), w in pair_counts.items()]

print("Weighted edges:", len(weighted_edgelist))
print("Sample:", weighted_edgelist[:5])
# Out:
# Weighted edges: 87076
# Sample: [('https://openalex.org/A5008033989', 'https://openalex.org/A5014647140', 5), ('https://openalex.org/A5008033989', 'https://openalex.org/A5067142016', 4), ('https://openalex.org/A5014647140', 'https://openalex.org/A5067142016', 4), ('https://openalex.org/A5014647140', 'https://openalex.org/A5082953212', 2), ('https://openalex.org/A5067142016', 'https://openalex.org/A5082953212', 1)]

# %%
G = nx.Graph()
G.add_weighted_edges_from(weighted_edgelist)

print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
# Out:
# Nodes: 21693
# Edges: 87076

# %%
first_pub_year = {}
for _, row in papers[["publication_year", "author_ids"]].dropna(subset=["publication_year"]).iterrows():
    y = int(row["publication_year"])
    for aid in row["author_ids"]:
        if isinstance(aid, str) and aid.startswith("http"):
            if aid not in first_pub_year or y < first_pub_year[aid]:
                first_pub_year[aid] = y

# %%
paper_cite_sum = defaultdict(int)
for _, row in papers[["cited_by_count", "author_ids"]].dropna(subset=["cited_by_count"]).iterrows():
    c = int(row["cited_by_count"])
    for aid in row["author_ids"]:
        if isinstance(aid, str) and aid.startswith("http"):
            paper_cite_sum[aid] += c

# %%
authors = authors.dropna(subset=["id"]).copy()
authors["id"] = authors["id"].astype(str)
author_meta = authors.set_index("id").to_dict(orient="index")

# %%
for node in G.nodes:
    meta = author_meta.get(node, {})
    G.nodes[node]["display_name"] = meta.get("display_name")
    G.nodes[node]["country_code"] = meta.get("country_code")
    # keep both if you have both
    G.nodes[node]["cited_by_count"] = meta.get("cited_by_count")  # from OpenAlex, if present
    G.nodes[node]["cited_by_count_from_papers"] = int(paper_cite_sum.get(node, 0))
    G.nodes[node]["first_publication_year_css"] = first_pub_year.get(node)

# quick check
next(iter(G.nodes(data=True)))
# Out:
# ('https://openalex.org/A5008033989',
#  {'display_name': 'Cristopher Moore',
#   'country_code': 'US',
#   'cited_by_count': 22140.0,
#   'cited_by_count_from_papers': 11540,
#   'first_publication_year_css': 2000})

# %%
data = nx.node_link_data(G)  # node-link format
with open("css_network.json", "w") as f:
    json.dump(data, f)

print("Saved css_network.json")
# Out:
# Saved css_network.json

# %% [markdown]
# # Part 2

# %%
n = G.number_of_nodes()
m = G.number_of_edges()

print("Nodes:", n)
print("Edges:", m)
print("Density:", nx.density(G))
print("Connected:", nx.is_connected(G) if n > 0 else False)

components = list(nx.connected_components(G)) if n > 0 else []
print("Connected components:", len(components))

isolates = list(nx.isolates(G))
print("Isolated nodes:", len(isolates))
# Out:
# Nodes: 21693
# Edges: 87076
# Density: 0.0003700916224553045
# Connected: False
# Connected components: 105
# Isolated nodes: 0

# %%
import numpy as np
import statistics as stats

degrees = np.array([d for _, d in G.degree()])
strengths = np.array([s for _, s in G.degree(weight="weight")])

def desc(arr):
    arr = arr.tolist()
    return {
        "mean": float(np.mean(arr)) if arr else None,
        "median": float(np.median(arr)) if arr else None,
        "mode": stats.multimode(arr)[:3] if arr else None,
        "min": int(np.min(arr)) if arr else None,
        "max": int(np.max(arr)) if arr else None
    }

print("Degree:", desc(degrees))
print("Strength:", desc(strengths))
# Out:
# Degree: {'mean': 8.028027474300465, 'median': 6.0, 'mode': [5], 'min': 1, 'max': 474}
# Strength: {'mean': 14.858341400451758, 'median': 8.0, 'mode': [4], 'min': 1, 'max': 720}

# %%
top5 = sorted(G.degree(), key=lambda x: x[1], reverse=True)[:5]
for aid, deg in top5:
    print(
        G.nodes[aid].get("display_name"),
        "| degree:", deg,
        "| strength:", G.degree(aid, weight="weight"),
        "| country:", G.nodes[aid].get("country_code"),
        "| id:", aid
    )
# Out:
# Yan Wang | degree: 474 | strength: 641 | country: CN | id: https://openalex.org/A5100322712
# Jiebo Luo | degree: 413 | strength: 720 | country: nan | id: https://openalex.org/A5055469774
# Lyle Ungar | degree: 274 | strength: 571 | country: nan | id: https://openalex.org/A5044944954
# Robert West | degree: 270 | strength: 533 | country: GB | id: https://openalex.org/A5059645286
# Alex Pentland | degree: 265 | strength: 584 | country: RU | id: https://openalex.org/A5007176508

# %% [markdown]
# Yan Wang: Networks and, ML, and computation
#
# Jiebo Luo: ML
#
# Lyle Ungar: Social Computation
#
# Robert West: Behavioral Science
#
# Alex Pentland: Computational Social Science

# %% [markdown]
# Take the network of Computational Social Scientists you built in the exercise above.
# To get an idea about how the network looks like, we start visualizing it. For this exercise, we will use the __awesome library [``netwulf``](https://netwulf.readthedocs.io/en/latest/index.html)__ created by Ulf Aslak and Ben Maier, two colleagues of mine.
# You can install it via ``pip install netwulf``.
#
# Netwulf is built on top of [d3-force](https://github.com/d3/d3-force), a Javascript library that simulates the dynamics of particles moving in 2D. In the visualization, particles correspond to network nodes subject to forces:
#  * Nodes are attracted to the center of the viz
#  * Nodes repel each other
#  * Nodes linked by an edge will preferably stay at a fixed distance to each other.
#
# Come and ask me if you want to know more!

# %% [markdown]
# > __Exercise 2: Visualize the network of Computational Social scientists.__
# >
# > * Extract the [largest connected components](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html) from your network. The largest connected component is the one with the largest number of nodes.
# > * Visualize the largest connected component using the function [``visualize``](https://netwulf.readthedocs.io/en/latest/reference/interactive.html?highlight=visualize#netwulf.interactive.visualize) of the Netwulf package.
# > * Play with the parameters of the netwulf algorithm to obtain a visualization you like. To understand better what the parameters mean, have a look at the [documentation](https://netwulf.readthedocs.io/en/latest/visualization/init.html?). Your visualization may look similar to the one below, where I made the size of nodes proportional to their strength (sum of weights of incoming edges), and I added the names of the top Computational Social Scientists by degree... But not necessarily! Just have fun making your own version. You can save the figure directly from the interactive visualization panel, or plot it in higher resolution in matplotlib following [this example](https://netwulf.readthedocs.io/en/latest/cookbook/cookbook.html#save-as-pdf).
# > * Describe the structure you observe. Can you identify nodes with a privileged position in the network?
# > * _Optional_: You can color nodes based on a property of your interest (e.g. country, citations). For example, I colored nodes based on their country. What do you observe? Can you find specific nodes properties that seem to correlate with a node's position in the network?
# >
# > **Note:** I encourage you to use Netwulf because they enable to make better visualizations, but you can also use the [draw](https://networkx.org/documentation/stable/reference/drawing.html) function built in NetworkX.
# >
# > __Go on [DTU Learn](https://learn.inside.dtu.dk/d2l/lms/survey/admin/surveys_manage.d2l?ou=296278) and complete the Survey: Week 4 - The Network__
#
# <img src="https://raw.githubusercontent.com/lalessan/comsocsci2026/master/images/network2.png" alt="Drawing" style="width: 800px;"/>

# %%
import pandas as pd
import networkx as nx
from networkx.readwrite import json_graph
from netwulf import visualize
from collections import Counter
import math, numpy as np

# --- helpers (same as before) ---
def json_safe_value(x):
    if isinstance(x, (np.integer,)): return int(x)
    if isinstance(x, (np.floating,)): x = float(x)
    if isinstance(x, float) and (math.isnan(x) or math.isinf(x)): return None
    if x is None or isinstance(x, (str, int, bool)): return x
    if isinstance(x, (list, tuple)): return [json_safe_value(v) for v in x]
    if isinstance(x, dict): return {str(k): json_safe_value(v) for k, v in x.items()}
    return str(x)

def sanitize_dataset_inplace(d):
    for n in d.get("nodes", []):
        for k, v in list(n.items()):
            n[k] = json_safe_value(v)
    for e in d.get("links", []):
        for k, v in list(e.items()):
            e[k] = json_safe_value(v)
    return d

# --- 1) compute top 5 countries in the LCC ---
countries = []
for n in G_lcc.nodes:
    cc = G_lcc.nodes[n].get("country_code")
    if isinstance(cc, str) and cc.strip():
        countries.append(cc)

top5_countries = [c for c, _ in Counter(countries).most_common(5)]
top5_set = set(top5_countries)
print("Top 5 countries in LCC:", top5_countries)

# assign group for coloring
for n in G_lcc.nodes:
    cc = G_lcc.nodes[n].get("country_code")
    G_lcc.nodes[n]["group"] = cc if cc in top5_set else "Other"

# --- 2) top 5 authors by degree -> labels ---
top5_authors = sorted(G_lcc.degree(), key=lambda x: x[1], reverse=True)[:5]
top5_author_ids = {aid for aid, _ in top5_authors}
print("Top 5 authors by degree:")
for aid, deg in top5_authors:
    print(deg, G_lcc.nodes[aid].get("display_name"), aid)

for n in G_lcc.nodes:
    if n in top5_author_ids:
        G_lcc.nodes[n]["label"] = G_lcc.nodes[n].get("display_name") or n
    else:
        G_lcc.nodes[n]["label"] = ""

# (optional) size nodes by strength (weighted degree)
nx.set_node_attributes(G_lcc, dict(G_lcc.degree(weight="weight")), "strength")

# --- 3) convert to netwulf dataset dict and fix edges->links ---
d = json_graph.node_link_data(G_lcc)
if "links" not in d and "edges" in d:
    d["links"] = d.pop("edges")

sanitize_dataset_inplace(d)

# --- 4) visualize ---
visualize(d)
# Out:
# Top 5 countries in LCC: ['US', 'CN', 'DE', 'GB', 'IT']
# Top 5 authors by degree:
# 474 Yan Wang https://openalex.org/A5100322712
# 413 Jiebo Luo https://openalex.org/A5055469774
# 274 Lyle Ungar https://openalex.org/A5044944954
# 270 Robert West https://openalex.org/A5059645286
# 265 Alex Pentland https://openalex.org/A5007176508
# ({'xlim': [0, 689],
#   'ylim': [0, 689],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 0.6,
#   'links': [{'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5014647140',
#     'width': 0.3,
#     'weight': 5},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5067142016',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5063648924',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5089831647',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5003817108',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5005302357',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5025745021',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5040634818',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5045651282',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5101479585',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5114948823',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5026230453',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5027136376',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5035455593',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5049359232',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5019087210',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5072560560',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5112033181',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5008033989',
#     'target': 'https://openalex.org/A5027937806',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5067142016',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5082953212',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5069948947',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5078253058',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5027079032',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5027903946',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5000038347',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5032779977',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5110544572',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5000679279',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5011168888',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5030987696',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5054707908',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5080732494',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5048132210',
#     'width': 0.3,
#     'weight': 5},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5054519023',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5054164320',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5036936081',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5055446394',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5101803962',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5101965096',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5045620226',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5072263832',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5063648924',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5089831647',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5037488679',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5110118358',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5088553895',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5011256345',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5011588754',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5048181040',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5018098888',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5037611969',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5074416333',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5000331865',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5014647140',
#     'target': 'https://openalex.org/A5073662865',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5082953212',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5058731900',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5082313934',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5043166229',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5052965447',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5082923475',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5079517520',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5038907218',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5043155699',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5085763758',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5064580861',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5067142016',
#     'target': 'https://openalex.org/A5070147321',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5045620226',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5062253481',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5071261828',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5112468935',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5064580861',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5082953212',
#     'target': 'https://openalex.org/A5074093929',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5069948947',
#     'target': 'https://openalex.org/A5078253058',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5007176508',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5024419925',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5041269206',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5016078038',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5000868394',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5023172399',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5031592048',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5060102759',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5015978876',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5048877432',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5052308997',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5101579932',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5105769246',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5112523317',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5015080044',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5018235085',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5111367077',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5000245456',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5032926589',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5073875709',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5021812568',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5111940488',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5051095866',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5103326255',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5078253058',
#     'target': 'https://openalex.org/A5112456168',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5027903946',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5048132210',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5054519023',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5011588754',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5048181040',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5055446394',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5006381131',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5015588148',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5018777562',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5039428882',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5054744757',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5057338010',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5032694172',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5054630728',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5082639817',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5007848139',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5014796446',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027079032',
#     'target': 'https://openalex.org/A5047384824',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5010495671',
#     'width': 0.3286335345030996,
#     'weight': 6},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5056499434',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5030079806',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5082330712',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5029418921',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5055710645',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5038976962',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5041695925',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5111672074',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5002753590',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5027903946',
#     'target': 'https://openalex.org/A5068655863',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5000038347',
#     'target': 'https://openalex.org/A5032779977',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5000038347',
#     'target': 'https://openalex.org/A5088553895',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5000038347',
#     'target': 'https://openalex.org/A5064274071',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5032779977',
#     'target': 'https://openalex.org/A5088553895',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5032779977',
#     'target': 'https://openalex.org/A5083939984',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5032779977',
#     'target': 'https://openalex.org/A5067254145',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5055922255',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5084047616',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5030724120',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5042503548',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5049281974',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5049393791',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5049639894',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5043683463',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5046973195',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5055244550',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5023617278',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5054116214',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5002429891',
#     'target': 'https://openalex.org/A5084679606',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5016098704',
#     'target': 'https://openalex.org/A5023997241',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5016098704',
#     'target': 'https://openalex.org/A5034076566',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5016098704',
#     'target': 'https://openalex.org/A5083303782',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5034076566',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5083303782',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5011368152',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5013262618',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5023775697',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5056559023',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5061483794',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5073459923',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5077079991',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5089434641',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5055398131',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5002312975',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5033827593',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5043042424',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5070497645',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5079255095',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5088507100',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5091065215',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5023997241',
#     'target': 'https://openalex.org/A5029616498',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5034076566',
#     'target': 'https://openalex.org/A5083303782',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5083303782',
#     'target': 'https://openalex.org/A5022713919',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5083303782',
#     'target': 'https://openalex.org/A5029191515',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5083303782',
#     'target': 'https://openalex.org/A5071818172',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5083303782',
#     'target': 'https://openalex.org/A5028488990',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5083303782',
#     'target': 'https://openalex.org/A5019007566',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5110544572',
#     'target': 'https://openalex.org/A5044995158',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5039380414',
#     'width': 0.3794733192202055,
#     'weight': 8},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5052946514',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5055204791',
#     'width': 0.3,
#     'weight': 5},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5025502160',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5030420299',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5037524467',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5040550858',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5014322193',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5030874155',
#     'target': 'https://openalex.org/A5077063699',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5052946514',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5055204791',
#     'width': 0.3,
#     'weight': 5},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5025502160',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5034823602',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5015709853',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5030420299',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5037524467',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039380414',
#     'target': 'https://openalex.org/A5040550858',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5052946514',
#     'target': 'https://openalex.org/A5055204791',
#     'width': 0.3794733192202055,
#     'weight': 8},
#    {'source': 'https://openalex.org/A5052946514',
#     'target': 'https://openalex.org/A5040550858',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5055204791',
#     'target': 'https://openalex.org/A5034823602',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5055204791',
#     'target': 'https://openalex.org/A5040550858',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5057083249',
#     'target': 'https://openalex.org/A5064296964',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5057083249',
#     'target': 'https://openalex.org/A5079825006',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5079825006',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5007176508',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5057243118',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5071122166',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5087990460',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5101702632',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5000679279',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5027814433',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5071294124',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5069454833',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5069999998',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5077079119',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5103706325',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5076633756',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5011229206',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5013559230',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5073189960',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5075956753',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5102756489',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5109833231',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5115598991',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5019872513',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5035743198',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5047234002',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5043639182',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5111367077',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5056499434',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5073565809',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5033977409',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5038699799',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5046561315',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5064296964',
#     'target': 'https://openalex.org/A5103326255',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5007176508',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5028277052',
#     'width': 0.3794733192202055,
#     'weight': 8},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5043737321',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5043896474',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5005339370',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5038255653',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5081335111',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5076189854',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5020025569',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5036639779',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5021537631',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5085034251',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5034680150',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5079825006',
#     'target': 'https://openalex.org/A5084449778',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5058635743',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5075497327',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5103264849',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5016314032',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5027320968',
#     'width': 0.3286335345030996,
#     'weight': 6},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5027462458',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5046029043',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5071024354',
#     'width': 0.40249223594996214,
#     'weight': 9},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5088459011',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5063175331',
#     'width': 0.35496478698597694,
#     'weight': 7},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5073734131',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5035352636',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5074409311',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5089509156',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5059294229',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5002732360',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5024799204',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5084868777',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5026740608',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5046105839',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5077149161',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5108737070',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5111951947',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5113037514',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5022230602',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5073030515',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5085572513',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5034329650',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5066276682',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5082650287',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5015934450',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5024635294',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5034268751',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5073547083',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5062137671',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5031768560',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5006794474',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5058796248',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5042474249',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5013338448',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5082717327',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5039995516',
#     'target': 'https://openalex.org/A5101517875',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5058635743',
#     'target': 'https://openalex.org/A5075497327',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5058635743',
#     'target': 'https://openalex.org/A5103264849',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5103264849',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5000313412',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5021465030',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5009798144',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5018053342',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5075497327',
#     'target': 'https://openalex.org/A5031279419',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5057243118',
#     'width': 0.3286335345030996,
#     'weight': 6},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5071122166',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5087990460',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5101702632',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5011229206',
#     'width': 0.35496478698597694,
#     'weight': 7},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5013559230',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5073189960',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5075956753',
#     'width': 0.35496478698597694,
#     'weight': 7},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5102756489',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5109833231',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5115598991',
#     'width': 0.18973665961010275,
#     'weight': 2},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5056499434',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5073565809',
#     'width': 0.13416407864998736,
#     'weight': 1},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5085409762',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5029105520',
#     'width': 0.4242640687119285,
#     'weight': 10},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5055068182',
#     'width': 0.23237900077244497,
#     'weight': 3},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5109203386',
#     'width': 0.2683281572999747,
#     'weight': 4},
#    {'source': 'https://openalex.org/A5007176508',
#     'target': 'https://openalex.org/A5028277052',
#     'width': 0.13416407864998736,
#     'weight': 1},
# ...
#     'y_canvas': 46.43932395257798,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5037256572',
#     'x': -84.92213953907367,
#     'y': 274.6334920731104,
#     'x_canvas': 258.6155720921853,
#     'y_canvas': 330.5266984146221,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5023557891',
#     'x': 2425.7750016020855,
#     'y': 840.9061986818605,
#     'x_canvas': 760.7550003204169,
#     'y_canvas': 443.7812397363721,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5028651788',
#     'x': 2417.9953479782694,
#     'y': 857.5554476328218,
#     'x_canvas': 759.1990695956538,
#     'y_canvas': 447.11108952656434,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5038551389',
#     'x': 2431.2104449023977,
#     'y': 856.8391956068554,
#     'x_canvas': 761.8420889804794,
#     'y_canvas': 446.96783912137107,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5051917172',
#     'x': 2438.5029263006413,
#     'y': 844.0755292959757,
#     'x_canvas': 763.3005852601282,
#     'y_canvas': 444.4151058591951,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5086127905',
#     'x': 2281.9548779225033,
#     'y': 749.2061600376202,
#     'x_canvas': 731.9909755845006,
#     'y_canvas': 425.44123200752404,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5051629081',
#     'x': -1203.2293999336937,
#     'y': -235.2094549658235,
#     'x_canvas': 34.95412001326136,
#     'y_canvas': 228.55810900683534,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5060932978',
#     'x': -1210.4761500161308,
#     'y': -246.14240212596408,
#     'x_canvas': 33.504769996773945,
#     'y_canvas': 226.37151957480722,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5069179682',
#     'x': -1215.331571395482,
#     'y': -229.28198136170892,
#     'x_canvas': 32.53368572090372,
#     'y_canvas': 229.74360372765824,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5081241202',
#     'x': -128.41887967346315,
#     'y': -1153.0341942808388,
#     'x_canvas': 249.9162240653074,
#     'y_canvas': 44.99316114383231,
#     'radius': 1.3117884166607732,
#     'color': '#19e8d6'},
#    {'id': 'https://openalex.org/A5003112344',
#     'x': 2181.513093907462,
#     'y': 517.8591941778926,
#     'x_canvas': 711.9026187814923,
#     'y_canvas': 379.1718388355785,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5008586077',
#     'x': 2288.3851714546795,
#     'y': 849.8931380277583,
#     'x_canvas': 733.2770342909357,
#     'y_canvas': 445.5786276055516,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5010490290',
#     'x': 2069.5611516800127,
#     'y': 719.9067697832494,
#     'x_canvas': 689.5122303360024,
#     'y_canvas': 419.5813539566499,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5100629712',
#     'x': 2284.634140300826,
#     'y': 885.9461483394658,
#     'x_canvas': 732.526828060165,
#     'y_canvas': 452.78922966789315,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5014171363',
#     'x': -2171.371819846027,
#     'y': -831.8073407199653,
#     'x_canvas': -158.67436396920522,
#     'y_canvas': 109.23853185600703,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5063009807',
#     'x': -2154.413280000645,
#     'y': -754.3528690282475,
#     'x_canvas': -155.2826560001289,
#     'y_canvas': 124.7294261943506,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5064422833',
#     'x': -2159.565551429078,
#     'y': -766.4153550241803,
#     'x_canvas': -156.3131102858154,
#     'y_canvas': 122.31692899516403,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5076198856',
#     'x': -2167.3276381081,
#     'y': -752.0584466109631,
#     'x_canvas': -157.86552762161983,
#     'y_canvas': 125.18831067780746,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5003013177',
#     'x': -1372.0246302379298,
#     'y': 1024.7556744625836,
#     'x_canvas': 1.195073952414134,
#     'y_canvas': 480.55113489251664,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5006540958',
#     'x': -1380.8345111897588,
#     'y': 1015.0380405923142,
#     'x_canvas': -0.5669022379516377,
#     'y_canvas': 478.60760811846285,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5034524266',
#     'x': -1262.7742553894307,
#     'y': 985.8243883205345,
#     'x_canvas': 23.04514892211398,
#     'y_canvas': 472.76487766410685,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5064592115',
#     'x': -1387.946887211777,
#     'y': 1026.0588769782155,
#     'x_canvas': -1.9893774423553054,
#     'y_canvas': 480.81177539564305,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5045284572',
#     'x': 2489.9571916320156,
#     'y': 1055.2676790878807,
#     'x_canvas': 773.591438326403,
#     'y_canvas': 486.6535358175761,
#     'radius': 1.3117884166607732,
#     'color': '#19e8d6'},
#    {'id': 'https://openalex.org/A5053480593',
#     'x': 2480.581744579779,
#     'y': 1046.0945815515468,
#     'x_canvas': 771.7163489159557,
#     'y_canvas': 484.8189163103093,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5013584271',
#     'x': -1471.3953533669983,
#     'y': -905.4356693363895,
#     'x_canvas': -18.679070673399508,
#     'y_canvas': 94.51286613272217,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5020270223',
#     'x': -1085.1899483968762,
#     'y': -940.0920449080701,
#     'x_canvas': 58.562010320624864,
#     'y_canvas': 87.58159101838609,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5023342239',
#     'x': -1481.0229455506642,
#     'y': -875.6168100752864,
#     'x_canvas': -20.604589110132736,
#     'y_canvas': 100.47663798494281,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5035257828',
#     'x': -1512.1750092265222,
#     'y': -879.4053896744597,
#     'x_canvas': -26.835001845304305,
#     'y_canvas': 99.71892206510813,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5036568372',
#     'x': -1830.1604384587358,
#     'y': -689.9762169479361,
#     'x_canvas': -90.43208769174703,
#     'y_canvas': 137.60475661041284,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5037427711',
#     'x': -1029.5841510399136,
#     'y': -719.7031412551711,
#     'x_canvas': 69.68316979201734,
#     'y_canvas': 131.65937174896584,
#     'radius': 1.3117884166607732,
#     'color': '#19e8d6'},
#    {'id': 'https://openalex.org/A5043176712',
#     'x': -167.3661707540164,
#     'y': 779.1206625641619,
#     'x_canvas': 242.12676584919677,
#     'y_canvas': 431.42413251283233,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5004281470',
#     'x': 1219.208202108162,
#     'y': 1472.3262824779752,
#     'x_canvas': 519.4416404216323,
#     'y_canvas': 570.0652564955949,
#     'radius': 1.3117884166607732,
#     'color': '#7cab69'},
#    {'id': 'https://openalex.org/A5051534545',
#     'x': -89.76345589898759,
#     'y': 1453.446218712369,
#     'x_canvas': 257.6473088202025,
#     'y_canvas': 566.2892437424737,
#     'radius': 1.3117884166607732,
#     'color': '#7cab69'},
#    {'id': 'https://openalex.org/A5111458376',
#     'x': -263.88490380466817,
#     'y': 568.5846017965257,
#     'x_canvas': 222.8230192390664,
#     'y_canvas': 389.31692035930513,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5021766596',
#     'x': -1727.6622693728584,
#     'y': -1076.5074269074603,
#     'x_canvas': -69.93245387457154,
#     'y_canvas': 60.29851461850805,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5086573660',
#     'x': -1693.1417557948253,
#     'y': -1038.1409802101575,
#     'x_canvas': -63.02835115896494,
#     'y_canvas': 67.97180395796858,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5103536276',
#     'x': -1681.0963167835537,
#     'y': -1043.3325238155805,
#     'x_canvas': -60.61926335671063,
#     'y_canvas': 66.93349523688397,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5043471979',
#     'x': -25.388489733643457,
#     'y': -586.4967387331885,
#     'x_canvas': 270.52230205327135,
#     'y_canvas': 158.30065225336236,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5030338466',
#     'x': -459.7616388576405,
#     'y': 563.2815846248635,
#     'x_canvas': 183.64767222847195,
#     'y_canvas': 388.2563169249727,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5038037073',
#     'x': -436.04407001526,
#     'y': 483.25562168065187,
#     'x_canvas': 188.39118599694805,
#     'y_canvas': 372.2511243361304,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5045931243',
#     'x': -1317.0210768523461,
#     'y': -538.9585665662553,
#     'x_canvas': 12.195784629530863,
#     'y_canvas': 167.808286686749,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5003799524',
#     'x': -1681.1073951420242,
#     'y': -1018.6961103228174,
#     'x_canvas': -60.621479028404735,
#     'y_canvas': 71.8607779354366,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5017370248',
#     'x': -1676.4951616554952,
#     'y': -1030.975036535715,
#     'x_canvas': -59.69903233109892,
#     'y_canvas': 69.40499269285709,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5113495291',
#     'x': -966.8689823151625,
#     'y': -1927.7142139368666,
#     'x_canvas': 82.22620353696757,
#     'y_canvas': -109.94284278737314,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5015978876',
#     'x': -782.7639713030859,
#     'y': 521.5080514529766,
#     'x_canvas': 119.04720573938289,
#     'y_canvas': 379.9016102905953,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5012993271',
#     'x': -1290.4851698119132,
#     'y': -226.8596090572845,
#     'x_canvas': 17.502966037617455,
#     'y_canvas': 230.22807818854315,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5037829206',
#     'x': -1302.4343321750712,
#     'y': -218.81957099614073,
#     'x_canvas': 15.113133564985844,
#     'y_canvas': 231.83608580077188,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5067301450',
#     'x': -1297.9672763590568,
#     'y': -241.8567605770624,
#     'x_canvas': 16.00654472818877,
#     'y_canvas': 227.22864788458756,
#     'radius': 1.3117884166607732,
#     'color': '#d96799'},
#    {'id': 'https://openalex.org/A5090197777',
#     'x': -1306.057502323729,
#     'y': -231.53237337159078,
#     'x_canvas': 14.388499535254311,
#     'y_canvas': 229.29352532568188,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5039370883',
#     'x': -1793.0949059725147,
#     'y': 3.989480850304833,
#     'x_canvas': -83.01898119450277,
#     'y_canvas': 276.397896170061,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5075927708',
#     'x': -1802.1052018049566,
#     'y': 14.989078996640517,
#     'x_canvas': -84.82104036099116,
#     'y_canvas': 278.59781579932815,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5080162030',
#     'x': -1806.1273398171088,
#     'y': 2.504403065057631,
#     'x_canvas': -85.62546796342161,
#     'y_canvas': 276.10088061301155,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5039902797',
#     'x': -280.67261889802035,
#     'y': 772.5679377834189,
#     'x_canvas': 219.46547622039597,
#     'y_canvas': 430.1135875566838,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5000107760',
#     'x': 274.3351425600499,
#     'y': 536.1714970714157,
#     'x_canvas': 330.46702851200996,
#     'y_canvas': 382.8342994142831,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5081457786',
#     'x': 1434.6603526766307,
#     'y': 1217.310987013677,
#     'x_canvas': 562.532070535326,
#     'y_canvas': 519.0621974027354,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5012514362',
#     'x': -1009.5895126734063,
#     'y': -1973.1003306150067,
#     'x_canvas': 73.68209746531883,
#     'y_canvas': -119.02006612300119,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5098559569',
#     'x': -117.24134834326253,
#     'y': 721.0742153093754,
#     'x_canvas': 252.15173033134752,
#     'y_canvas': 419.8148430618751,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5098559570',
#     'x': -130.3277549952961,
#     'y': 720.1850102604789,
#     'x_canvas': 249.5344490009408,
#     'y_canvas': 419.6370020520958,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5014870940',
#     'x': -426.61316162942865,
#     'y': 537.1845971516977,
#     'x_canvas': 190.27736767411432,
#     'y_canvas': 383.03691943033954,
#     'radius': 1.3117884166607732,
#     'color': '#6098dc'},
#    {'id': 'https://openalex.org/A5005397644',
#     'x': -1733.2773215470138,
#     'y': -1057.9143577636771,
#     'x_canvas': -71.05546430940262,
#     'y_canvas': 64.01712844726467,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5080421508',
#     'x': -1700.224450349016,
#     'y': -1020.0473243462941,
#     'x_canvas': -64.44489006980308,
#     'y_canvas': 71.59053513074127,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5090367526',
#     'x': -1694.4087979380627,
#     'y': -1008.2905002369465,
#     'x_canvas': -63.281759587612385,
#     'y_canvas': 73.94189995261078,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5044404041',
#     'x': 389.4824495107224,
#     'y': -1059.1077094605066,
#     'x_canvas': 353.4964899021445,
#     'y_canvas': 63.778458107898786,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5066864733',
#     'x': -777.219975842868,
#     'y': 676.4032631410427,
#     'x_canvas': 120.15600483142649,
#     'y_canvas': 410.8806526282085,
#     'radius': 1.3117884166607732,
#     'color': '#80c70e'},
#    {'id': 'https://openalex.org/A5021333390',
#     'x': 91.38148709756285,
#     'y': -836.0788808493122,
#     'x_canvas': 293.8762974195126,
#     'y_canvas': 108.38422383013761,
#     'radius': 1.3117884166607732,
#     'color': '#19e8d6'},
#    ...]},
#  {'zoom': 0.6,
#   'node_charge': -45,
#   'node_gravity': 0.1,
#   'link_distance': 4.38742663177993,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': False,
#   'freeze_nodes': False,
#   'node_fill_color': '#79aaa0',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 6.558942083303868,
#   'node_stroke_width': 1,
#   'node_size_variation': 3,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})
